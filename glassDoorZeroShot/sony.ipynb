# %% [markdown]
# Importing data from Google Sheets
#
# Referencing snippet from here: https://colab.research.google.com/notebooks/snippets/sheets.ipynb#scrollTo=JiJVCmu3dhFa

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from google.auth import default
creds, _ = default()

gc = gspread.authorize(creds)

# %%
worksheet = gc.open('allSonyGlassdoor').sheet1

# %%
rows = worksheet.get_all_values()
print(rows)
# Out:
# [['title', 'author_info', 'rating', 'pros', 'cons', 'helpful'], ['Excellent company', 'Jun 1, 2022 - Service Engineer in Miami, FL', '5', 'Excellent company to work for', 'None to share, great environment to grow', 'Be the first to find this review helpful'], ['friendly environment', 'May 28, 2022 - Program Manager', '5', 'colleges are friendly and supportive. work-life balanced.', "There's not much room for young people to grow up", 'Be the first to find this review helpful'], ['Great Company', 'May 16, 2022 - Summer Intern in Herndon, VA', '5', 'I learned a lot in this company. The team is amazing and it is very supportive. a lot of flexibility.', 'Sometimes it is hard to make connections with other people.', 'Be the first to find this review helpful'], ['Sony review', 'May 11, 2022 - Anonymous Employee', '5', 'Good pay really solid culture', 'its not flexible depending on department', 'Be the first to find this review helpful'], ['no comments', 'May 24, 2022 - Senior Research Engineer', '2', 'work with smart people work with cutting edge technology', 'toxic working environment low paid terrible WLB', 'Be the first to find this review helpful'], ['Nice', 'May 4, 2022 - Anonymous Employee', '5', 'A great place to work', 'I hate working at this place!', 'Be the first to find this review helpful'], ['Great work environment', 'Apr 26, 2022 - Front End Developer in Johannesburg, MI', '5', 'Salary Work hours Health Care', 'Benefits Culture Work hours Health Care', 'Be the first to find this review helpful'], ['Great Place', 'Apr 25, 2022 - Director of Development in New York, NY', '5', 'Creative environment that empowers you.', 'Not many cons to speak of.', 'Be the first to find this review helpful'], ['Sony GISD', 'Mar 30, 2022 - Senior Manager Cybersecurity', '2', "Sony as a company is great. Benefits are really good. Salaries are good. Sony as a whole cares about it's employees.", "GISD (the security group for Sony) is the worst organization to work for. Upper management refuses to make decisions then blames employees for lack of progress. Too many people in the org don't have any understanding of security or good enough IT knowledge to work at this level. Moral is low in most groups. If you are lucky enough to work in a group that actually has high moral it may not last long.", 'Be the first to find this review helpful'], ['Good company', 'Apr 21, 2022 - Programmer Analyst in New York, NY', '5', 'very good company to work', 'food in the kitchen was not good', 'Be the first to find this review helpful'], ['Good', 'May 3, 2022 - Anonymous Employee', '4', 'good working atmosphere on site', 'Will have some overtime hours', 'Be the first to find this review helpful'], ['nice place', 'May 2, 2022 - Consultant in New York, NY', '3', 'Office space is very nice', 'I do not have any', 'Be the first to find this review helpful'], ['Very good', 'Apr 11, 2022 - Product Manager in New York, NY', '5', 'fast promotion with competitive compensation', 'salary promotion is not that good', 'Be the first to find this review helpful'], ['Good work', 'Apr 6, 2022 - Associate Consultant in New Haven, CT', '5', 'Fun time working there in Sony', 'Long hours sometimes but it is okay', 'Be the first to find this review helpful'], ['Best place to work', 'Apr 21, 2022 - Anonymous Employee', '2', 'Culture is great and growth opportunities', 'It is a a far drive', 'Be the first to find this review helpful'], ['Artist', 'Apr 4, 2022 - Level Artist in San Diego, CA', '5', 'was a an excellent workplace', 'hard work and high standards for demanding projects', 'Be the first to find this review helpful'], ['great employer', 'Mar 31, 2022 - Cyber Intel Analyst in Herndon, VA', '5', 'fun, laid back environment with a bunch of opportunites', 'pay is lower than other places', 'Be the first to find this review helpful'], ['great overall', 'Mar 29, 2022 - Sales Assistant in New York, NY', '5', 'Really flexible schedule, fun environment, learn from others', "Kind of stri ...

# %% [markdown]
# Converting the spreadsheet to a Pandas Dataframe

# %%
import pandas as pd

# %%
sony_df = pd.DataFrame.from_records(rows)
display(sony_df)
# Out:
#                                                       0  \
# 0                                                 title
# 1                                     Excellent company
# 2                                  friendly environment
# 3                                         Great Company
# 4                                           Sony review
# ...                                                 ...
# 2003  Good company but there are better salaries and...
# 2004                               The Sun Sets on Sony
# 2005               Sony Ericsson has amazing employees.
# 2006  It's an allright place to work, probably one o...
# 2007  Sony Ericsson - a well recomended company to s...
#
#                                                     1       2  \
# 0                                         author_info  rating
# 1         Jun 1, 2022 - Service Engineer in Miami, FL       5
# 2                      May 28, 2022 - Program Manager       5
# 3         May 16, 2022 - Summer Intern in Herndon, VA       5
# 4                   May 11, 2022 - Anonymous Employee       5
# ...                                               ...     ...
# 2003   Jun 4, 2009 - Software Engineer in Lund, Skåne       4
# 2004  Mar 20, 2009 - Director in Basingstoke, England       3
# 2005    Feb 24, 2009 - General Manager in Lund, Skåne       5
# 2006                 Dec 22, 2008 - Research Engineer       3
# 2007                   Aug 21, 2008 - Section Manager       4
#
#                                                       3  \
# 0                                                  pros
# 1                         Excellent company to work for
# 2     colleges are friendly and supportive. work-lif...
# 3     I learned a lot in this company. The team is a...
# 4                         Good pay really solid culture
# ...                                                 ...
# 2003  Lots of own responsibility. Managment in swede...
# 2004  Lots of cheap toys in the staff shop Kind cult...
# 2005  The people are extremely passionate about thei...
# 2006  Access to research resources seem good, not a ...
# 2007  There's lots to do - you get a lot of responsi...
#
#                                                       4  \
# 0                                                  cons
# 1              None to share, great environment to grow
# 2     There's not much room for young people to grow up
# 3     Sometimes it is hard to make connections with ...
# 4              its not flexible depending on department
# ...                                                 ...
# 2003  hard to correct bad salary and hard to advance...
# 2004  Long hours Inflexible Poor leaders Japanese ge...
# 2005  Sony uses it as either a place to send old exe...
# 2006  Some internal supervision is poor. Got hired a...
# 2007  No attention to quality. Macho management styl...
#
#                                              5
# 0                                      helpful
# 1     Be the first to find this review helpful
# 2     Be the first to find this review helpful
# 3     Be the first to find this review helpful
# 4     Be the first to find this review helpful
# ...                                        ...
# 2003        1 person found this review helpful
# 2004  Be the first to find this review helpful
# 2005  Be the first to find this review helpful
# 2006  Be the first to find this review helpful
# 2007  Be the first to find this review helpful
#
# [2008 rows x 6 columns]

# %%
# Designating the first row of the dataframe as the header
sony_df.columns = sony_df.iloc[0]
sony_df = sony_df[1:]
sony_df.head()
# Out:
# 0                 title                                  author_info rating  \
# 1     Excellent company  Jun 1, 2022 - Service Engineer in Miami, FL      5
# 2  friendly environment               May 28, 2022 - Program Manager      5
# 3         Great Company  May 16, 2022 - Summer Intern in Herndon, VA      5
# 4           Sony review            May 11, 2022 - Anonymous Employee      5
# 5           no comments      May 24, 2022 - Senior Research Engineer      2
#
# 0                                               pros  \
# 1                      Excellent company to work for
# 2  colleges are friendly and supportive. work-lif...
# 3  I learned a lot in this company. The team is a...
# 4                      Good pay really solid culture
# 5  work with smart people work with cutting edge ...
#
# 0                                               cons  \
# 1           None to share, great environment to grow
# 2  There's not much room for young people to grow up
# 3  Sometimes it is hard to make connections with ...
# 4           its not flexible depending on department
# 5    toxic working environment low paid terrible WLB
#
# 0                                   helpful
# 1  Be the first to find this review helpful
# 2  Be the first to find this review helpful
# 3  Be the first to find this review helpful
# 4  Be the first to find this review helpful
# 5  Be the first to find this review helpful

# %% [markdown]
# Cleaning up the dataframe by...
#
# - Removing the `helpful` (last) column, which indicates how many Glassdoor users rated a review as "helpful." This information is not relevant to us.
# - Parsing the date from the `author_info` (second) column. While job titles are not always provided – as review authors are not obligated by Glassdoor to state them — they are spliced out whenever they are. This allows us to only access the information we need: the date the review was posted.

# %%
# Remove last column by its title
sony_df = sony_df.drop('helpful', 1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only

# %%
import datetime

# %%
# Helper function for date formatting (MM/DD/YY).
# i.e. Takes "Jan 1, 2000" as input, and returns "01/01/2000" as output.
# Note that both I/O are strings.
def format_date(original_date):

  date_components = original_date.split(' ')

  # Convert the month from abbreviated to numerical format.
  # Pad zeroes wherever appropriate.
  month_published = str(datetime.datetime.strptime(date_components[0], "%b").month).zfill(2)

  # Remove the trailing comma from the day (second item in list).
  # Again, pad zeroes wherever appropriate.
  day_published = date_components[1][0:-1].zfill(2)

  year_published = date_components[2]

  date_formatted = month_published + '/' + day_published + '/' + year_published
  return date_formatted

# %%
sony_df.head()
# Out:
# 0                 title                                  author_info rating  \
# 1     Excellent company  Jun 1, 2022 - Service Engineer in Miami, FL      5
# 2  friendly environment               May 28, 2022 - Program Manager      5
# 3         Great Company  May 16, 2022 - Summer Intern in Herndon, VA      5
# 4           Sony review            May 11, 2022 - Anonymous Employee      5
# 5           no comments      May 24, 2022 - Senior Research Engineer      2
#
# 0                                               pros  \
# 1                      Excellent company to work for
# 2  colleges are friendly and supportive. work-lif...
# 3  I learned a lot in this company. The team is a...
# 4                      Good pay really solid culture
# 5  work with smart people work with cutting edge ...
#
# 0                                               cons
# 1           None to share, great environment to grow
# 2  There's not much room for young people to grow up
# 3  Sometimes it is hard to make connections with ...
# 4           its not flexible depending on department
# 5    toxic working environment low paid terrible WLB

# %%
def format_dates_in_df(df_original):
  df = df_original.copy()

  # Extract the date from the last column
  for index, row in df.iterrows():

    delimiter = ' - '
    split_info = row['author_info'].split(delimiter)
    
    date_published = ''

    # If a job title was provided by the reviewer, we splice it out.
    if len(split_info) > 1:
      date_published = split_info[0]

    # If no job title was provided, then the date is simply
    # the first item in the list, with the trailing space & hyphen excluded.
    # So exclude the last two characters.
    else:
      date_published = split_info[0][0:-2]
    
    # Format the date, relying on the helper function above.
    date_formatted = format_date(date_published)
    
    # Update the dataframe.
    df.loc[index, 'author_info'] = date_formatted
  
  return df

# %%
formatted_sony_df = format_dates_in_df(sony_df)

# %%
# # Extract the date from the last column
# for index, row in sony_df.iterrows():

#   delimiter = ' - '
#   split_info = row['author_info'].split(delimiter)
  
#   date_published = ''

#   # If a job title was provided by the reviewer, we splice it out.
#   if len(split_info) > 1:
#     date_published = split_info[0]

#   # If no job title was provided, then the date is simply
#   # the first item in the list, with the trailing space & hyphen excluded.
#   # So exclude the last two characters.
#   else:
#     date_published = split_info[0][0:-2]
  
#   # Format the date, relying on the helper function above.
#   print(date_published)
#   date_formatted = format_date(date_published)
#   # date_formatted = date_published
  
#   # Update the dataframe.
#   sony_df.loc[index, 'author_info'] = date_formatted

# %%
formatted_sony_df.head()
# Out:
# 0                 title author_info rating  \
# 1     Excellent company  06/01/2022      5
# 2  friendly environment  05/28/2022      5
# 3         Great Company  05/16/2022      5
# 4           Sony review  05/11/2022      5
# 5           no comments  05/24/2022      2
#
# 0                                               pros  \
# 1                      Excellent company to work for
# 2  colleges are friendly and supportive. work-lif...
# 3  I learned a lot in this company. The team is a...
# 4                      Good pay really solid culture
# 5  work with smart people work with cutting edge ...
#
# 0                                               cons
# 1           None to share, great environment to grow
# 2  There's not much room for young people to grow up
# 3  Sometimes it is hard to make connections with ...
# 4           its not flexible depending on department
# 5    toxic working environment low paid terrible WLB

# %% [markdown]
# ### Retroactive date handling (pt. 1)

# %%
import nltk
nltk.download('punkt')
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
from nltk.tokenize import word_tokenize
from pprint import pprint
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.

# %%
lemmatizer = WordNetLemmatizer()

def tokenizeLemmatize(reviews):
  temp = []
  for sentence in reviews:
    tokens = word_tokenize(sentence)
    cleanedSentence = ""
    for token in tokens:
        lemmetized_word = lemmatizer.lemmatize(token)
        cleanedSentence += lemmetized_word + " "
    temp.append(cleanedSentence)
  return temp

# %%
# Initializing a Python dictionary wherein
# keys: the tokenized, lemmatized review sentence
# values: the date (MM/DD/YY) that review was posted on

# Helper function
# Returns sentences as list
def parse_sentences_from_review_block(review):

  list_of_sentences = []
  
  current_sentence = ''
  previous_char = review[0]
  
  for character in review:
    
    # Encounter period -> assume sentence
    if character == '.':
      if current_sentence.strip('-. ') and not current_sentence.strip(',. ').isspace():
        list_of_sentences.append(current_sentence.strip('-.'))
      # Reset
      current_sentence = ''
    
    # Encounter hyphen -> assume sentence
    elif character == ' ' and previous_char == '-':
      if current_sentence.strip('-. ') and not current_sentence.strip(',. ').isspace():
        list_of_sentences.append(current_sentence.strip('.-'))
      # Reset
      current_sentence = ''
    
    # Continue
    current_sentence += character
    previous_char = character
  
  # Append whatever's left, if it hasn't already been caught
  if current_sentence.strip('-. ') and not current_sentence.strip(',. ').isspace():
    list_of_sentences.append(current_sentence.strip('.-'))
  
  return list_of_sentences

# column_name is either 'pros' or 'cons'
def create_dates_dictionary(df, column_name):
  dates_dict = {}

  for index, row in df.iterrows():

    date_string = row['author_info']
    review = row[column_name]

    review_sentences = parse_sentences_from_review_block(review)
    cleaned_sentences = tokenizeLemmatize(review_sentences)
    # print(cleaned_sentences)

    for each_sentence in cleaned_sentences:
      dates_dict[each_sentence] = date_string
    
  return dates_dict

# %%
dates_dict_pros = create_dates_dictionary(formatted_sony_df, "pros")
print(dates_dict_pros)
# Out:
# {'Excellent company to work for ': '06/01/2022', 'college are friendly and supportive ': '05/28/2022', 'work-life balanced ': '05/28/2022', 'I learned a lot in this company ': '07/28/2016', 'The team is amazing and it is very supportive ': '05/16/2022', 'a lot of flexibility ': '05/16/2022', 'Good pay really solid culture ': '05/11/2022', 'work with smart people work with cutting edge technology ': '05/24/2022', 'A great place to work ': '02/03/2021', 'Salary Work hour Health Care ': '04/26/2022', 'Creative environment that empowers you ': '04/25/2022', 'Sony a a company is great ': '03/30/2022', 'Benefits are really good ': '03/30/2022', 'Salaries are good ': '03/30/2022', "Sony a a whole care about it 's employee ": '03/30/2022', 'very good company to work ': '04/21/2022', 'good working atmosphere on site ': '05/03/2022', 'Office space is very nice ': '05/02/2022', 'fast promotion with competitive compensation ': '04/11/2022', 'Fun time working there in Sony ': '04/06/2022', 'Culture is great and growth opportunity ': '04/21/2022', 'wa a an excellent workplace ': '04/04/2022', 'fun , laid back environment with a bunch of opportunites ': '03/31/2022', 'Really flexible schedule , fun environment , learn from others ': '03/29/2022', 'Great company to work for excellent leadership ': '03/24/2022', 'Great perk benefit ': '03/24/2022', 'it a paycheck i guess ': '04/05/2022', 'Hands on with latest tech , good discount ': '04/03/2022', 'Lots of studio experience , interact with all part of the company ': '03/30/2022', 'Great benefit , dentist and gym on-site ': '03/30/2022', 'Working for Sony is a great experience ! ! ': '03/11/2022', 'great company to work for ': '11/18/2020', 'Great community and you meet a lot of people ': '03/04/2022', 'Cool place to work at ': '03/14/2022', 'Great office with nice People ': '03/13/2022', 'Great benefit ': '02/24/2016', 'Great pay , no micromanaging and amazing coworkers ': '02/24/2022', 'Sony had a great corporate structure ': '02/21/2022', 'Good pay ': '02/08/2013', 'and great people and experience ': '02/14/2022', 'Good company with ton of benefit ! Salary is great ! Work load varies by the team ': '02/27/2022', 'Treats employee with respect ': '02/27/2022', 'Interesting environment and an easy company to learn quickly on the job ': '02/24/2022', 'Good company to work , not much pressure ': '02/24/2022', 'Nice people ': '08/31/2021', 'Great , interesting work ': '01/31/2022', 'Great benefit , lot of potential ( squandered ) ': '02/12/2022', 'Love the job and the people ! ': '01/25/2022', 'Lots of job security , so you can build a career there ': '01/24/2022', 'It wa a great place to work ': '01/25/2022', 'Good environment , good extra and good teamwork ': '01/21/2022', 'Great company ': '03/14/2017', 'Very professional , good environment ': '01/19/2022', 'the pay wa really good ': '02/02/2022', 'Great work-life balance and benefit ': '01/18/2022', 'Good work good company good hour ': '01/16/2022', 'Good employment benefit manager is nice ': '01/14/2022', 'Good work and life balance ': '08/27/2015', 'Great people to work with ': '08/30/2019', 'Top level benefit amongst MNC Comfortable and ideal environment for working till retirement ': '01/04/2022', 'Get to see celebrity and cool campus ': '01/24/2022', 'Nice benefit and overall good compensation structure with 401k ': '01/02/2022', 'Good Work life balance Passionate people Decent compensation ': '12/29/2021', 'Great company to work for ': '03/14/2021', 'Good work atmosphere ': '08/21/2019', 'Great people ': '05/21/2014', 'Good pay and company culture ': '12/23/2021', 'Work on a variety of different issue ': '12/20/2021', 'Good pay Great communication Friendly work environment ': '12/20/2021', 'good environment forworker to communicate ': '11/30/2021', 'Good company to work for ': '12/19/2018', 'Work across a variety of entertainment and technology avenue ': '12/09/2021', 'Travel and good for your resume ': '12/05/2021', 'The employee discoun ...

# %%
dates_dict_cons = create_dates_dictionary(formatted_sony_df, "cons")
print(dates_dict_cons)
# Out:
# {'None to share , great environment to grow ': '06/01/2022', "There 's not much room for young people to grow up ": '05/28/2022', 'Sometimes it is hard to make connection with other people ': '05/16/2022', 'it not flexible depending on department ': '05/11/2022', 'toxic working environment low paid terrible WLB ': '05/24/2022', 'I hate working at this place ! ': '05/04/2022', 'Benefits Culture Work hour Health Care ': '04/26/2022', 'Not many con to speak of ': '04/25/2022', 'GISD ( the security group for Sony ) is the worst organization to work for ': '03/30/2022', 'Upper management refuse to make decision then blame employee for lack of progress ': '03/30/2022', "Too many people in the org do n't have any understanding of security or good enough IT knowledge to work at this level ": '03/30/2022', 'Moral is low in most group ': '03/30/2022', 'If you are lucky enough to work in a group that actually ha high moral it may not last long ': '03/30/2022', 'food in the kitchen wa not good ': '04/21/2022', 'Will have some overtime hour ': '05/03/2022', 'I do not have any ': '05/02/2022', 'salary promotion is not that good ': '04/11/2022', 'Long hour sometimes but it is okay ': '04/06/2022', 'It is a a far drive ': '04/21/2022', 'hard work and high standard for demanding project ': '04/04/2022', 'pay is lower than other place ': '03/31/2022', "Kind of strict but I mean what job is n't ": '03/29/2022', 'No more retail marketing department ': '03/24/2022', 'still the bastion corporate america ': '04/05/2022', 'No room for growth ': '11/21/2014', "Does n't like to promote within ": '04/03/2022', 'Hard place to grow , very political , can be toxic work environment ': '03/30/2022', 'While working for Sony I havnt experienced any con ': '03/11/2022', 'worldwide office are the best ': '03/23/2022', 'Little benefit if you are working a a production assistant ': '03/04/2022', 'Some people can ’ t take a joke ': '03/14/2022', 'Hard product to sell , technology wa not there ': '03/13/2022', 'Nothing ! It wa a phenomenal experience ': '02/24/2022', "I did n't feel like I had much creative control ": '02/21/2022', 'None , the internship wa perfect ': '02/14/2022', 'Cronies and favoritism pull down other pro ! Management should pay attention on this area ': '02/27/2022', 'High expectation ( little room for error ) ': '02/24/2022', 'Slow progress , management , talent , project ': '02/24/2022', 'I didn ’ t have any con ': '01/31/2022', 'Highly political , people unwilling to take risk or put forth opinion , lack of alignment on group goal , LOTS of ego , arrogance and clique ': '02/12/2022', 'No downside to this job ': '01/25/2022', 'Risk of catching Covid on the lot ': '01/24/2022', "I do n't see any con ": '12/08/2020', 'I don ’ t have any negative point ': '01/21/2022', 'None , can ’ t think of one flaw ': '01/19/2022', 'wa laid off in 2013 ': '02/02/2022', 'Some system used internally are not very efficient ': '01/18/2022', 'too much work tight deadline sometimes unclear brief ': '01/16/2022', 'Sometime heavy workload on project ': '01/14/2022', 'No a lot of growth opportunity ': '01/21/2022', 'Not a great place for pay hike ': '01/04/2022', 'Too conservative business strategy Unwilling to explore new industry like diagnostics , wasting the cutting edge technology ': '01/04/2022', 'If bos doesn ’ t like you , they will put you on a performance plan ': '01/24/2022', 'Impossible to appease ': '01/24/2022', 'Worked 7 day a week , 15 hour day ': '01/24/2022', 'The management is a mess and should be dealt with ': '01/02/2022', 'Average management Top down culture Mediocre calibration and review process ': '12/29/2021', 'There is no con in my job ': '12/15/2021', 'I just want s change ': '12/15/2021', 'Nice place to work at ': '12/11/2021', 'Somewhat quick employee turnaround at the company ': '12/23/2021', 'Hard to move up and can sometimes be long hour ': '12/20/2021', 'Late hour Toxic hr Crowded work station ': '12/20/2021', 'need more push in proje ...

# %% [markdown]
# # Zero-shot classification
#
# Now, we're going to use zero-shot classification to classify our reviews
# according to these axes: Culture and Values, Diversity and Inclusion, Work/Life Balance, Senior Management, Compensation and Benefits, and Career Opportunities.
#
# To do this, we'll first make a long list of all the sentences from our reviews.
#
# Then, we'll use BART from Hugging Face (https://huggingface.co/facebook/bart-large-mnli) to classify those sentences, putting them into appropriate lists! We will also keep them separated by negative and positive by assuming that whatever is under "pros" is positive, and whatever is under "cons" can be expected to be negative--this will be useful later on when we begin to use BERT for sentiment analysis.

# %%
pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.19.2-py3-none-any.whl (4.2 MB)
#      |████████████████████████████████| 4.2 MB 5.0 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 55.0 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.7.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.11.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.7.0-py3-none-any.whl (86 kB)
#      |████████████████████████████████| 86 kB 5.5 MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.0)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 42.0 MB/s
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (4.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.8.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2022.5.18.1)
# Installing collected packages: pyyaml, tokenizers, huggingface-hub, transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.7.0 pyyaml-6.0 tokenizers-0.12.1 transformers-4.19.2

# %%
from transformers import pipeline
classifier = pipeline("zero-shot-classification",
                      model="facebook/bart-large-mnli")
# Out:
# Downloading:   0%|          | 0.00/1.13k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.52G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.29M [00:00<?, ?B/s]

# %%
reviewsPro = formatted_sony_df['pros']      # pros column
reviewsCon = formatted_sony_df['cons']      # cons column

# %% [markdown]
# Now that we have our data, we need to parse things into sentences. This is a bit tricky--there's no unified format for user reviews. Some people use periods to separate sentences. Some use hyphens. Some use both hyphens and periods, with additional hyphens. When the data is scraped from the Internet, newlines are obliterated, so we can't use those as clues.
#
# Instead, we'll assume that if we encounter a period or an exclamation mark, we're ending a sentence. We'll also assume that if we encounter a hyphen with a space after it, we're ending a sentence.

# %%
proSentences = []
conSentences = []

def parseSentencesFromReviewsColumn(reviewsColumn, reviewsList):
  # Iterate through the review at each row in the given column.
  for (columnName, columnData) in reviewsColumn.iteritems():
    currSent = ""
    prevChar = columnData[0]
    # columnData = one full positive review section. Loop thru char by char
    for character in columnData:
      # If we encounter a period, assume sentence, but only if the built string is
      # not spaces and not empty.
      if character == '.':
        if currSent.strip("-. ") and not currSent.strip(",. ").isspace():
          reviewsList.append(currSent.strip("-."))
        currSent = ""
      # If we encounter a "- ", assume sentence.
      elif character == ' ' and prevChar == '-':
        if currSent.strip("-. ") and not currSent.strip(",. ").isspace():
          reviewsList.append(currSent.strip(".-"))
      
        currSent = ""
    
      # Keep building the string and keep track of the prev char.
      currSent += character
      prevChar = character
      
    # Append whatever was left if it wasn't already caught
    if currSent.strip("-. ") and not currSent.strip(",. ").isspace():
      reviewsList.append(currSent.strip(".-"))

# Run on positive and negative reviews
parseSentencesFromReviewsColumn(reviewsPro, proSentences)
parseSentencesFromReviewsColumn(reviewsCon, conSentences)

# Sanity check
print(proSentences[:15])
print(conSentences[:15])
# Out:
# ['Excellent company to work for', 'colleges are friendly and supportive', ' work-life balanced', 'I learned a lot in this company', ' The team is amazing and it is very supportive', ' a lot of flexibility', 'Good pay really solid culture', 'work with smart people work with cutting edge technology', 'A great place to work', 'Salary Work hours Health Care', 'Creative environment that empowers you', 'Sony as a company is great', ' Benefits are really good', ' Salaries are good', " Sony as a whole cares about it's employees"]
# ['None to share, great environment to grow', "There's not much room for young people to grow up", 'Sometimes it is hard to make connections with other people', 'its not flexible depending on department', 'toxic working environment low paid terrible WLB', 'I hate working at this place!', 'Benefits Culture Work hours Health Care', 'Not many cons to speak of', 'GISD (the security group for Sony) is the worst organization to work for', ' Upper management refuses to make decisions then blames employees for lack of progress', " Too many people in the org don't have any understanding of security or good enough IT knowledge to work at this level", ' Moral is low in most groups', ' If you are lucky enough to work in a group that actually has high moral it may not last long', 'food in the kitchen was not good', 'Will have some overtime hours']

# %%
import nltk
nltk.download('punkt')
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
from nltk.tokenize import word_tokenize
from pprint import pprint
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.

# %%
lemmatizer = WordNetLemmatizer()

def tokenizeLemmetize(reviews):
  temp = []
  for sentence in reviews:
    tokens = word_tokenize(sentence)
    cleanedSentence = ""
    for token in tokens:
        lemmetized_word = lemmatizer.lemmatize(token)
        cleanedSentence += lemmetized_word + " "
    temp.append(cleanedSentence)
  return temp

# %%
proSentencesCleaned = tokenizeLemmetize(proSentences)
conSentencesCleaned = tokenizeLemmetize(conSentences)

# Sanity check
print(proSentencesCleaned[:15])
print(conSentencesCleaned[:15])
# Out:
# ['Excellent company to work for ', 'college are friendly and supportive ', 'work-life balanced ', 'I learned a lot in this company ', 'The team is amazing and it is very supportive ', 'a lot of flexibility ', 'Good pay really solid culture ', 'work with smart people work with cutting edge technology ', 'A great place to work ', 'Salary Work hour Health Care ', 'Creative environment that empowers you ', 'Sony a a company is great ', 'Benefits are really good ', 'Salaries are good ', "Sony a a whole care about it 's employee "]
# ['None to share , great environment to grow ', "There 's not much room for young people to grow up ", 'Sometimes it is hard to make connection with other people ', 'it not flexible depending on department ', 'toxic working environment low paid terrible WLB ', 'I hate working at this place ! ', 'Benefits Culture Work hour Health Care ', 'Not many con to speak of ', 'GISD ( the security group for Sony ) is the worst organization to work for ', 'Upper management refuse to make decision then blame employee for lack of progress ', "Too many people in the org do n't have any understanding of security or good enough IT knowledge to work at this level ", 'Moral is low in most group ', 'If you are lucky enough to work in a group that actually ha high moral it may not last long ', 'food in the kitchen wa not good ', 'Will have some overtime hour ']

# %% [markdown]
# Now we're all set up to classify our sentences. We'll sort them into lists according to their valence and category (the six categories are given under "Zero-shot classification)--12 lists in total.

# %%
# These are the possible categories of relevance we have defined.
# Diversity and inclusion = 1
# Culture and values = 2
# Work life balance = 3
# Senior management = 4
# Career opportunities = 5
# Compensation and benefits = 6
candidate_labels = ['diversity and inclusion', 'culture and values', 'work life balance', 'senior management', 'career opportunities', 'compensation and benefits']
pro1 = []
con1 = []
pro2 = []
con2 = []
pro3 = []
con3 = []
pro4 = []
con4 = []
pro5 = []
con5 = []
pro6 = []
con6 = []

pros = [pro1, pro2, pro3, pro4, pro5, pro6]
cons = [con1, con2, con3, con4, con5, con6]

# Let's be picky and assume that if the top value is lower than 0.4, the
# sentence is not relevant.

def sortReviewSentencesUsingZeroShot(sentenceList, labeledContainers):
  for sentence in sentenceList:
    cat = classifier(sentence, candidate_labels)
    if float(cat['scores'][0]) > 0.4:
      label = cat['labels'][0]
      if label == candidate_labels[0]:
        labeledContainers[0].append(sentence)
      elif label == candidate_labels[1]:
        labeledContainers[1].append(sentence)
      elif label == candidate_labels[2]:
        labeledContainers[2].append(sentence)
      elif label == candidate_labels[3]:
        labeledContainers[3].append(sentence)
      elif label == candidate_labels[4]:
        labeledContainers[4].append(sentence)
      elif label == candidate_labels[5]:
        labeledContainers[5].append(sentence)

# %%
# Libraries needed to import/export files from/to drive
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# Each list item is written on a separate line: lists within the list are 
# separated with the token "[LISTSEP]". For the filepath, you need to 
# input a directory that already exists in your drive. (e.g., 
# /content/drive/MyDrive/folderYouCreated/fileNameYouWant)

def writeListOfListsToFile(listThingy, filePath):
  with open(filePath, 'w') as writefile:
    for oneList in listThingy:
      for element in oneList:
        writefile.write(element)
        writefile.write('\n')
      writefile.write("[LISTSEP]\n")

# %%
sortReviewSentencesUsingZeroShot(proSentencesCleaned, pros)
writeListOfListsToFile(pros, '/content/drive/MyDrive/new_sony/sonyProsClassified_FIXED.txt')

# %%
sortReviewSentencesUsingZeroShot(conSentencesCleaned, cons)
writeListOfListsToFile(cons, '/content/drive/MyDrive/new_sony/sonyConsClassified_FIXED.txt')

# %% [markdown]
# Now we'll print some classifiers and store them for our confusion matrix.

# %%
def printClassifiersForConfusion(sentenceList, howMany, filePath):
    # print(classifier(sentenceList[count], candidate_labels))
  with open(filePath, 'w') as writefile:
    for i in range(howMany):
      writefile.write(str(classifier(sentenceList[i], candidate_labels)))
      writefile.write("\n")

# %%
printClassifiersForConfusion(proSentencesCleaned, 25, '/content/drive/MyDrive/new_sony/sonyPosConfusion_FIXED.txt')

# %%
printClassifiersForConfusion(conSentencesCleaned, 25, '/content/drive/MyDrive/new_sony/sonyNegConfusion_FIXED.txt')

# %% [markdown]
# ### Retroactive date handling (pt. 2)
#
# Producing a "parallel" text file of dates that, line-by-line, matches each sentence from the classification file with its authorship date.

# %%
print(dates_dict_pros)
# Out:
# {'Excellent company to work for ': '06/01/2022', 'college are friendly and supportive ': '05/28/2022', 'work-life balanced ': '05/28/2022', 'I learned a lot in this company ': '07/28/2016', 'The team is amazing and it is very supportive ': '05/16/2022', 'a lot of flexibility ': '05/16/2022', 'Good pay really solid culture ': '05/11/2022', 'work with smart people work with cutting edge technology ': '05/24/2022', 'A great place to work ': '02/03/2021', 'Salary Work hour Health Care ': '04/26/2022', 'Creative environment that empowers you ': '04/25/2022', 'Sony a a company is great ': '03/30/2022', 'Benefits are really good ': '03/30/2022', 'Salaries are good ': '03/30/2022', "Sony a a whole care about it 's employee ": '03/30/2022', 'very good company to work ': '04/21/2022', 'good working atmosphere on site ': '05/03/2022', 'Office space is very nice ': '05/02/2022', 'fast promotion with competitive compensation ': '04/11/2022', 'Fun time working there in Sony ': '04/06/2022', 'Culture is great and growth opportunity ': '04/21/2022', 'wa a an excellent workplace ': '04/04/2022', 'fun , laid back environment with a bunch of opportunites ': '03/31/2022', 'Really flexible schedule , fun environment , learn from others ': '03/29/2022', 'Great company to work for excellent leadership ': '03/24/2022', 'Great perk benefit ': '03/24/2022', 'it a paycheck i guess ': '04/05/2022', 'Hands on with latest tech , good discount ': '04/03/2022', 'Lots of studio experience , interact with all part of the company ': '03/30/2022', 'Great benefit , dentist and gym on-site ': '03/30/2022', 'Working for Sony is a great experience ! ! ': '03/11/2022', 'great company to work for ': '11/18/2020', 'Great community and you meet a lot of people ': '03/04/2022', 'Cool place to work at ': '03/14/2022', 'Great office with nice People ': '03/13/2022', 'Great benefit ': '02/24/2016', 'Great pay , no micromanaging and amazing coworkers ': '02/24/2022', 'Sony had a great corporate structure ': '02/21/2022', 'Good pay ': '02/08/2013', 'and great people and experience ': '02/14/2022', 'Good company with ton of benefit ! Salary is great ! Work load varies by the team ': '02/27/2022', 'Treats employee with respect ': '02/27/2022', 'Interesting environment and an easy company to learn quickly on the job ': '02/24/2022', 'Good company to work , not much pressure ': '02/24/2022', 'Nice people ': '08/31/2021', 'Great , interesting work ': '01/31/2022', 'Great benefit , lot of potential ( squandered ) ': '02/12/2022', 'Love the job and the people ! ': '01/25/2022', 'Lots of job security , so you can build a career there ': '01/24/2022', 'It wa a great place to work ': '01/25/2022', 'Good environment , good extra and good teamwork ': '01/21/2022', 'Great company ': '03/14/2017', 'Very professional , good environment ': '01/19/2022', 'the pay wa really good ': '02/02/2022', 'Great work-life balance and benefit ': '01/18/2022', 'Good work good company good hour ': '01/16/2022', 'Good employment benefit manager is nice ': '01/14/2022', 'Good work and life balance ': '08/27/2015', 'Great people to work with ': '08/30/2019', 'Top level benefit amongst MNC Comfortable and ideal environment for working till retirement ': '01/04/2022', 'Get to see celebrity and cool campus ': '01/24/2022', 'Nice benefit and overall good compensation structure with 401k ': '01/02/2022', 'Good Work life balance Passionate people Decent compensation ': '12/29/2021', 'Great company to work for ': '03/14/2021', 'Good work atmosphere ': '08/21/2019', 'Great people ': '05/21/2014', 'Good pay and company culture ': '12/23/2021', 'Work on a variety of different issue ': '12/20/2021', 'Good pay Great communication Friendly work environment ': '12/20/2021', 'good environment forworker to communicate ': '11/30/2021', 'Good company to work for ': '12/19/2018', 'Work across a variety of entertainment and technology avenue ': '12/09/2021', 'Travel and good for your resume ': '12/05/2021', 'The employee discoun ...

# %%
print(dates_dict_cons)
# Out:
# {'None to share , great environment to grow ': '06/01/2022', "There 's not much room for young people to grow up ": '05/28/2022', 'Sometimes it is hard to make connection with other people ': '05/16/2022', 'it not flexible depending on department ': '05/11/2022', 'toxic working environment low paid terrible WLB ': '05/24/2022', 'I hate working at this place ! ': '05/04/2022', 'Benefits Culture Work hour Health Care ': '04/26/2022', 'Not many con to speak of ': '04/25/2022', 'GISD ( the security group for Sony ) is the worst organization to work for ': '03/30/2022', 'Upper management refuse to make decision then blame employee for lack of progress ': '03/30/2022', "Too many people in the org do n't have any understanding of security or good enough IT knowledge to work at this level ": '03/30/2022', 'Moral is low in most group ': '03/30/2022', 'If you are lucky enough to work in a group that actually ha high moral it may not last long ': '03/30/2022', 'food in the kitchen wa not good ': '04/21/2022', 'Will have some overtime hour ': '05/03/2022', 'I do not have any ': '05/02/2022', 'salary promotion is not that good ': '04/11/2022', 'Long hour sometimes but it is okay ': '04/06/2022', 'It is a a far drive ': '04/21/2022', 'hard work and high standard for demanding project ': '04/04/2022', 'pay is lower than other place ': '03/31/2022', "Kind of strict but I mean what job is n't ": '03/29/2022', 'No more retail marketing department ': '03/24/2022', 'still the bastion corporate america ': '04/05/2022', 'No room for growth ': '11/21/2014', "Does n't like to promote within ": '04/03/2022', 'Hard place to grow , very political , can be toxic work environment ': '03/30/2022', 'While working for Sony I havnt experienced any con ': '03/11/2022', 'worldwide office are the best ': '03/23/2022', 'Little benefit if you are working a a production assistant ': '03/04/2022', 'Some people can ’ t take a joke ': '03/14/2022', 'Hard product to sell , technology wa not there ': '03/13/2022', 'Nothing ! It wa a phenomenal experience ': '02/24/2022', "I did n't feel like I had much creative control ": '02/21/2022', 'None , the internship wa perfect ': '02/14/2022', 'Cronies and favoritism pull down other pro ! Management should pay attention on this area ': '02/27/2022', 'High expectation ( little room for error ) ': '02/24/2022', 'Slow progress , management , talent , project ': '02/24/2022', 'I didn ’ t have any con ': '01/31/2022', 'Highly political , people unwilling to take risk or put forth opinion , lack of alignment on group goal , LOTS of ego , arrogance and clique ': '02/12/2022', 'No downside to this job ': '01/25/2022', 'Risk of catching Covid on the lot ': '01/24/2022', "I do n't see any con ": '12/08/2020', 'I don ’ t have any negative point ': '01/21/2022', 'None , can ’ t think of one flaw ': '01/19/2022', 'wa laid off in 2013 ': '02/02/2022', 'Some system used internally are not very efficient ': '01/18/2022', 'too much work tight deadline sometimes unclear brief ': '01/16/2022', 'Sometime heavy workload on project ': '01/14/2022', 'No a lot of growth opportunity ': '01/21/2022', 'Not a great place for pay hike ': '01/04/2022', 'Too conservative business strategy Unwilling to explore new industry like diagnostics , wasting the cutting edge technology ': '01/04/2022', 'If bos doesn ’ t like you , they will put you on a performance plan ': '01/24/2022', 'Impossible to appease ': '01/24/2022', 'Worked 7 day a week , 15 hour day ': '01/24/2022', 'The management is a mess and should be dealt with ': '01/02/2022', 'Average management Top down culture Mediocre calibration and review process ': '12/29/2021', 'There is no con in my job ': '12/15/2021', 'I just want s change ': '12/15/2021', 'Nice place to work at ': '12/11/2021', 'Somewhat quick employee turnaround at the company ': '12/23/2021', 'Hard to move up and can sometimes be long hour ': '12/20/2021', 'Late hour Toxic hr Crowded work station ': '12/20/2021', 'need more push in proje ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
category_delimiter = "[LISTSEP]\n"

def match_dates(filename_read, dates_dict):

  # Reading from file of classified review sentences
  f_read = open(filename_read, "r")
  classified_lines = f_read.readlines()

  dates_in_classification_order = []

  for line in classified_lines:
    if line != category_delimiter:

      # Remove trailing newline & leading whitespacing (single space)
      line_stripped = line.rstrip('\n').lstrip(' ')

      # Remove leading whitespace (single space)
      # line_bare_2 = line_bare.lstrip(' ')

      date_string = dates_dict[line_stripped]
      dates_in_classification_order.append(date_string)
    else:
      dates_in_classification_order.append(category_delimiter)
  
  # Writing corresponding dates into another file
  # f_write = open(filename_write, "w")

  f_read.close()
  
  return dates_in_classification_order

# %%
dates_pros = match_dates('/content/drive/MyDrive/new_sony/sonyProsClassified_FIXED.txt', dates_dict_pros)

# %%
print(dates_pros)
# Out:
# ['03/04/2022', '10/25/2021', '02/10/2021', '01/24/2021', '12/30/2020', '11/10/2020', '03/11/2020', '11/09/2019', '05/09/2019', '04/13/2019', '12/03/2017', '02/05/2016', '12/26/2015', '12/07/2015', '11/17/2015', '10/16/2015', '03/28/2015', '03/04/2015', '01/27/2015', '01/08/2015', '05/31/2013', '09/17/2010', '05/02/2010', '05/22/2022', '09/19/2021', '08/30/2021', '08/05/2021', '07/09/2021', '03/21/2021', '03/10/2021', '01/02/2021', '09/17/2020', '06/24/2020', '06/02/2020', '07/13/2019', '05/12/2019', '04/01/2019', '03/11/2019', '11/13/2018', '06/10/2018', '03/16/2018', '09/12/2017', '08/15/2017', '05/22/2017', '04/04/2017', '01/24/2017', '01/24/2017', '01/21/2017', '12/12/2016', '09/22/2016', '09/19/2016', '07/19/2016', '07/15/2016', '04/21/2016', '04/18/2016', '01/17/2016', '06/10/2015', '07/19/2014', '05/21/2014', '01/07/2014', '10/30/2013', '09/05/2013', '06/24/2013', '06/24/2013', '06/22/2013', '03/07/2013', '10/20/2012', '09/19/2012', '09/23/2012', '08/25/2012', '08/22/2012', '08/03/2012', '02/16/2012', '09/06/2011', '01/29/2011', '01/06/2011', '08/19/2010', '08/02/2010', '05/11/2010', '05/09/2010', '[LISTSEP]\n', '03/30/2022', '04/21/2022', '02/21/2022', '02/27/2022', '10/13/2021', '10/08/2021', '10/05/2021', '05/10/2021', '03/31/2021', '03/04/2021', '01/15/2021', '01/12/2021', '12/12/2020', '11/23/2020', '10/21/2020', '08/26/2020', '08/14/2020', '04/30/2020', '04/04/2020', '04/04/2020', '11/07/2019', '11/05/2019', '09/19/2019', '08/26/2019', '03/26/2019', '12/12/2018', '11/24/2018', '10/19/2018', '09/27/2018', '05/22/2018', '04/03/2018', '03/29/2018', '01/09/2018', '05/15/2017', '03/12/2017', '02/10/2017', '10/03/2016', '10/01/2016', '05/18/2016', '04/25/2016', '04/05/2016', '02/05/2016', '01/06/2016', '12/26/2015', '12/10/2015', '08/26/2015', '06/08/2015', '06/10/2015', '05/05/2015', '04/16/2015', '04/05/2015', '03/15/2015', '02/12/2015', '01/08/2015', '12/22/2014', '11/04/2014', '09/30/2014', '07/27/2014', '04/17/2014', '02/27/2014', '12/18/2013', '09/30/2013', '02/27/2013', '02/22/2013', '11/09/2012', '11/09/2012', '06/27/2012', '07/21/2011', '11/01/2010', '05/02/2010', '12/23/2008', '12/23/2008', '10/25/2008', '10/23/2008', '05/24/2022', '01/05/2016', '05/28/2022', '05/03/2022', '04/26/2022', '04/07/2022', '03/18/2022', '03/15/2022', '03/15/2022', '02/12/2022', '02/06/2022', '01/26/2022', '02/03/2022', '01/15/2022', '01/02/2022', '01/06/2022', '01/01/2022', '12/13/2021', '12/10/2021', '12/07/2021', '12/07/2021', '11/23/2021', '11/18/2021', '11/24/2021', '11/19/2021', '11/15/2021', '10/11/2021', '10/11/2021', '09/24/2021', '09/02/2021', '09/26/2021', '08/05/2021', '08/01/2021', '07/30/2021', '07/29/2021', '07/16/2021', '07/09/2021', '06/12/2021', '06/16/2021', '05/31/2021', '05/22/2021', '04/29/2021', '04/17/2021', '04/07/2021', '04/06/2021', '03/21/2021', '02/10/2021', '01/02/2021', '12/24/2020', '12/09/2020', '11/26/2020', '12/09/2020', '11/26/2020', '11/02/2020', '10/13/2020', '09/27/2020', '09/17/2020', '09/17/2020', '09/17/2020', '09/20/2020', '10/16/2020', '10/16/2020', '07/15/2020', '07/09/2020', '06/21/2020', '06/20/2020', '04/07/2020', '03/18/2020', '02/15/2020', '01/29/2020', '01/10/2020', '01/02/2020', '12/30/2019', '12/26/2019', '11/24/2019', '11/14/2019', '10/19/2019', '10/19/2019', '10/24/2019', '08/21/2019', '08/21/2019', '07/06/2019', '06/28/2019', '06/06/2019', '05/20/2019', '05/21/2019', '05/19/2019', '05/07/2019', '05/01/2019', '02/11/2019', '02/23/2019', '11/30/2018', '11/13/2018', '10/11/2018', '09/01/2018', '08/09/2018', '07/05/2018', '06/27/2018', '06/26/2018', '05/31/2018', '04/26/2018', '04/13/2018', '04/07/2018', '03/29/2018', '03/19/2018', '03/19/2018', '03/12/2018', '03/18/2018', '02/18/2018', '02/13/2018', '03/08/2018', '12/19/2017', '12/02/2017', '12/11/2017', '12/06/2017', '11/07/2017', '11/05/2017', '10/13/2017', '09/06/2017', '08/29/2017', '09/06/2017', '09/03/2017', '08/30/2017', '07/12/2017', '07/06/2017', '06/30/2017', '06/13/2017', '05/17/2017', '05/01/2017', '04/13/2017', '04/16/2 ...

# %%
dates_cons = match_dates('/content/drive/MyDrive/new_sony/sonyConsClassified.txt', dates_dict_cons)

# %%
print(dates_cons)
# Out:
# ['09/29/2020', '02/25/2016', '11/19/2015', '06/08/2015', '05/02/2010', '10/23/2021', '07/20/2021', '03/23/2021', '11/04/2020', '06/01/2020', '07/23/2012', '12/06/2011', '10/15/2011', '[LISTSEP]\n', '03/30/2022', '03/30/2022', '04/04/2022', '02/24/2022', '02/12/2022', '12/29/2021', '12/05/2021', '08/23/2021', '06/21/2021', '03/04/2021', '10/14/2020', '08/08/2020', '05/13/2020', '05/13/2020', '04/07/2020', '04/04/2020', '04/04/2020', '02/04/2020', '01/13/2020', '11/04/2019', '08/12/2019', '05/31/2019', '05/31/2019', '04/13/2019', '03/07/2019', '02/13/2019', '09/27/2018', '09/27/2018', '09/27/2018', '09/06/2018', '05/22/2018', '03/19/2018', '01/26/2018', '12/05/2017', '05/20/2017', '04/26/2017', '05/13/2017', '04/10/2017', '02/14/2017', '02/10/2017', '11/29/2016', '09/19/2016', '07/18/2016', '07/18/2016', '07/12/2016', '04/25/2016', '04/02/2016', '12/01/2015', '09/02/2015', '08/26/2015', '07/29/2015', '06/17/2015', '06/01/2015', '06/11/2015', '06/11/2015', '05/01/2015', '04/25/2015', '03/31/2015', '03/10/2015', '03/06/2015', '02/05/2015', '01/08/2015', '01/08/2015', '04/09/2014', '03/16/2014', '02/27/2014', '02/08/2014', '10/11/2013', '08/06/2013', '05/31/2013', '05/31/2013', '05/31/2013', '03/13/2013', '11/19/2012', '07/21/2011', '07/21/2011', '04/20/2011', '01/29/2011', '06/29/2010', '02/12/2010', '02/12/2010', '02/12/2010', '04/10/2009', '07/31/2008', '07/31/2008', '06/27/2008', '05/07/2022', '05/04/2022', '03/15/2022', '01/27/2022', '01/03/2022', '01/05/2022', '11/23/2021', '12/05/2021', '11/18/2021', '11/30/2021', '11/24/2021', '12/12/2021', '11/03/2021', '10/08/2021', '08/30/2021', '09/07/2021', '09/26/2021', '06/22/2021', '05/21/2021', '05/04/2021', '05/03/2021', '05/17/2021', '03/28/2021', '03/21/2021', '03/04/2021', '02/25/2021', '02/01/2021', '01/26/2021', '01/08/2021', '12/23/2020', '11/16/2020', '11/11/2020', '11/01/2020', '10/21/2020', '09/23/2020', '09/20/2020', '05/05/2020', '03/18/2020', '01/13/2020', '11/24/2019', '11/05/2019', '10/12/2019', '10/08/2019', '08/21/2019', '08/12/2019', '07/06/2019', '07/31/2019', '07/31/2019', '07/31/2019', '07/31/2019', '07/31/2019', '06/18/2019', '05/20/2019', '04/19/2019', '02/22/2019', '12/27/2018', '10/11/2018', '09/28/2018', '09/28/2018', '09/28/2018', '08/21/2018', '08/01/2018', '08/02/2018', '06/28/2018', '06/26/2018', '06/05/2018', '05/01/2018', '03/19/2018', '03/18/2018', '03/18/2018', '03/08/2018', '12/21/2017', '12/14/2017', '10/24/2017', '09/06/2017', '08/10/2017', '07/12/2017', '07/01/2017', '06/26/2017', '06/14/2017', '05/17/2017', '03/13/2017', '02/03/2017', '10/22/2016', '10/17/2016', '09/19/2016', '09/06/2016', '08/25/2016', '07/15/2016', '07/01/2016', '04/16/2016', '04/26/2016', '04/24/2016', '04/24/2016', '04/24/2016', '04/24/2016', '03/03/2016', '01/28/2016', '01/05/2016', '01/14/2016', '01/14/2016', '12/11/2015', '09/19/2015', '09/07/2015', '08/30/2015', '08/05/2015', '07/18/2015', '07/16/2015', '07/04/2015', '06/25/2015', '06/12/2015', '03/29/2015', '03/31/2015', '03/31/2015', '12/12/2014', '12/15/2014', '12/15/2014', '12/11/2014', '12/11/2014', '05/21/2014', '04/22/2014', '04/16/2014', '04/02/2014', '02/25/2014', '01/30/2014', '01/02/2014', '12/14/2013', '07/29/2013', '07/05/2013', '07/05/2013', '07/05/2013', '04/25/2013', '03/07/2013', '03/07/2013', '11/18/2012', '11/18/2012', '12/08/2012', '11/14/2012', '09/27/2012', '09/23/2012', '09/13/2012', '09/12/2012', '09/11/2012', '08/25/2012', '08/30/2012', '08/12/2012', '06/01/2012', '03/08/2012', '03/14/2012', '02/16/2012', '02/19/2012', '02/19/2012', '01/24/2012', '12/12/2011', '11/24/2011', '12/06/2011', '12/06/2011', '10/26/2011', '10/05/2011', '10/15/2011', '10/15/2011', '10/15/2011', '06/09/2011', '06/09/2011', '06/09/2011', '06/09/2011', '03/28/2011', '01/29/2011', '01/17/2011', '09/20/2010', '08/12/2010', '05/11/2010', '01/01/2010', '07/29/2009', '03/20/2009', '12/22/2008', '08/21/2008', '08/21/2008', '[LISTSEP]\n', '05/24/2022', '05/03/2022', '04/06/2022', '12/20/2021', '11/11/2021', '10/05/2021', '10/05/ ...

# %%
# Input:
#   (1) filepath
#   (2) resulting list of classification-ordered dates from match_dates
# Output:
#   Does not return anything, but writes dates to specified file(path).
def write_dates_to_file(filename_write, dates_ordered):

  f_write = open(filename_write, "w")

  for date_string in dates_ordered:
    # If [LISTSEP], don't write in newline
    if date_string[0] == "[":
      f_write.write("%s" % date_string)
    else:
      f_write.write("%s\n" % date_string)
  
  f_write.close()

# %%
# Pros
write_dates_to_file('/content/drive/MyDrive/dates/sonyPosDates.txt', dates_pros)

# %%
# Cons
write_dates_to_file('/content/drive/MyDrive/dates/sonyNegDates.txt', dates_cons)
